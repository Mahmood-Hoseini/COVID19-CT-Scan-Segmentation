# %%
import pandas as pd
import numpy as np
import scipy
import matplotlib.pyplot as plt
import seaborn
import cv2 as cv
import nibabel as nib
import pickle
import glob
import imgaug as ia
import imgaug.augmenters as iaa
import tqdm
import gc, os
import warnings
import tensorflow as tf
from keras import backend as K
from keras import losses, metrics
from keras import optimizers
from keras import callbacks
from keras.models import Model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers import concatenate, Conv2D, MaxPooling2D, Conv2DTranspose
from keras.layers import Multiply
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from skimage import morphology
from skimage import measure
#import keras_segmentation as ks

warnings.filterwarnings('ignore')
# %matplotlib inline
print("Version: ", tf.version.VERSION)
print("GPU is", "available" if tf.config.experimental.list_physical_devices("GPU") else "not available")
# Out:
# Version:  2.3.0
# GPU is available

# %% [markdown]
# ## 1. Loading data

# %%
datadir = '../training-set'
testdir = '../testing-set'

glob_search = os.path.join(datadir, 'patient*')
train_files = sorted(glob.glob(glob_search))
glob_search = os.path.join(testdir, 'patient*')
test_files = sorted(glob.glob(glob_search))

print('num of train patients {}, num of test patient {}'.format(len(train_files), len(test_files)))
# Out:
# num of train patients 19, num of test patient 1

# %% [markdown]
# # 2. EDA
#
# ### part one: Let's load images from the first patient and see what it looks like

# %%
# img_size is the preferred image size to which the image is to be resized
img_size = 512

glob_search = os.path.join(train_files[0], '*ctscan*.nii')
ct_file = glob.glob(glob_search)
print('CT filename: ', ct_file[0])
cts = nib.load(ct_file[0])
data = cts.get_fdata()

height, width, slices = data.shape
print('number of slices: ', slices)
print('image height is {} and width is {}'.format(height, width))
  
# lets plot some of them
data = np.rot90(np.array(data))
data = np.reshape(np.rollaxis(data, 2),(slices,height,width))

sel_slices = range(10,slices,30)
arr = data[sel_slices, :, :]


fig, axes = plt.subplots(2, 5, figsize=(15,6))
axes = axes.flatten()
for ii in range(arr.shape[0]):
    img = cv.resize(arr[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    xmax, xmin = img.max(), img.min()
    img = (img - xmin)/(xmax - xmin)
    axes[ii].imshow(img, cmap='bone')
    axes[ii].set_title("Original CT, slice #{}".format(sel_slices[ii]))
    axes[ii].set_xticks([])
    axes[ii].set_yticks([]);
plt.tight_layout()
# Out:
# CT filename:  ../training-set/patient01/patient01-ctscan.nii
# number of slices:  301
# image height is 512 and width is 512

# %% [markdown]
# Now we are going to enhance the imaes and drop the first and last 20% of slices

# %%
clahe = cv.createCLAHE(clipLimit=3.0)

def clahe_enhancer(img, clahe, axes):
    '''Contrast Limited Adaptive Histogram Equalizer'''
    img = np.uint8(img*255)  
    clahe_img = clahe.apply(img)

    if len(axes) > 0 :    
        axes[0].imshow(img, cmap='bone')
        axes[0].set_title("Original CT")
        axes[0].set_xticks([]); axes[0].set_yticks([])

        axes[1].imshow(clahe_img, cmap='bone')
        axes[1].set_title("CLAHE Enhanced CT")
        axes[1].set_xticks([]); axes[1].set_yticks([])

        if len(axes) > 2 :
            axes[2].hist(img.flatten(), alpha=0.4, label='Original CT')
            axes[2].hist(clahe_img.flatten(), alpha=0.4, label="CLAHE Enhanced CT")
            plt.legend()
        
    return(clahe_img)

# %%
sel_slices = range(70, 240, 30)
arr = data[sel_slices, :, :]

fig, axes = plt.subplots(3, 6, figsize=(18,8))    
for ii in range(arr.shape[0]):
    img = cv.resize(arr[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    xmax, xmin = img.max(), img.min()
    img = (img - xmin)/(xmax - xmin)
    clahe_img = clahe_enhancer(img, clahe, list(axes[:, ii]))
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
def crop_(img, boundaries):
    minx, miny, maxx, maxy = boundaries
    return img[minx:maxx, miny:maxy]

def make_lungmask(img, img_size=512, display_flag=False):
    height, width = img.shape
    img = (img-np.mean(img))/np.std(img)

    # Find the average pixel value near the lungs
    middle = img[int(width/5):int(width/5*4),int(height/5):int(height/5*4)] 
    mean = np.mean(middle)  
    imgmax = np.max(img)
    imgmin = np.min(img)
    
    img[img==imgmax]=mean
    img[img==imgmin]=mean
    
    # Using Kmeans to separate foreground (soft tissue / bone) and background (lung/air)
    kmeans = KMeans(n_clusters=2).fit(np.reshape(middle,[np.prod(middle.shape),1]))
    centers = sorted(kmeans.cluster_centers_.flatten())
    threshold = np.mean(centers)
    thresh_img = np.where(img<threshold,1.0,0.0)  # threshold the image

    # First erode away the finer elements, then dilate to include some of the pixels surrounding the lung.  
    # We don't want to accidentally clip the lung.
    eroded = morphology.erosion(thresh_img,np.ones([3,3]))
    dilation = morphology.dilation(eroded,np.ones([8,8]))

    labels = measure.label(dilation) # Different labels are displayed in different colors
    label_vals = np.unique(labels)
    regions = measure.regionprops(labels)
    good_labels = []
    try :
        Lung1 = regions[1].bbox
        Lung2 = regions[2].bbox
        bounds = [min(Lung1[0], Lung2[0]), min(Lung1[1], Lung2[1]),
                  max(Lung1[2], Lung2[2]), max(Lung1[3], Lung2[3])]
    except :
        bounds = [img_size, img_size, 0, 0] # return extreme values

    if display_flag:
        fig, ax = plt.subplots(1, 5, figsize=[15, 3])
        ax[0].set_title("Original CT")
        ax[0].imshow(img, cmap='bone')
        ax[0].axis('off')
        ax[1].set_title("Threshold")
        ax[1].imshow(thresh_img, cmap='bone')
        ax[1].axis('off')
        ax[2].set_title("After Erosion & Dilation")
        ax[2].imshow(dilation, cmap='bone')
        ax[2].axis('off')
        ax[3].set_title("Colored labels")
        ax[3].imshow(labels)
        ax[3].axis('off')
        ax[4].set_title("Cropped CT")
        ax[4].imshow(crop_(img, bounds), cmap='bone')
        ax[4].axis('off')
        plt.show()
        
    return bounds

bounds = make_lungmask(arr[3], display_flag=True)

# %% [markdown]
# **Define helper functions**
#
# There are a lot of empty spac in the images that can be cropped out. This makes the model run faster!

# %%
sel_slices = range(70, 240, 30)
arr = data[sel_slices, :, :]

bounds = [img_size, img_size, 0, 0]
for ii in range(arr.shape[0]) :
    img = cv.resize(arr[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    B = make_lungmask(img, img_size=img_size, display_flag=False)
    bounds[0] = min(bounds[0], B[0])
    bounds[1] = min(bounds[1], B[1])
    bounds[2] = max(bounds[2], B[2])
    bounds[3] = max(bounds[3], B[3])
    
    
fig, axes = plt.subplots(2, 6, figsize=(18,6))    
for ii in range(arr.shape[0]):
    img = cv.resize(arr[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    axes[0,ii].imshow(img, cmap='bone')
    axes[0,ii].set_title('Original CT')
    axes[0,ii].set_xticks([]); axes[0,ii].set_yticks([])
    
    img = crop_(img, bounds)
    axes[1,ii].imshow(img, cmap='bone')
    axes[1,ii].set_title('Cropped CT')
    axes[1,ii].set_xticks([]); axes[1,ii].set_yticks([])

# %% [markdown]
# ### part two: Visualizing sample lung and infection masks

# %%
glob_search = os.path.join(train_files[0], '*ctscan*.nii')
ct_file = glob.glob(glob_search)
print('CT filename: ', ct_file[0])
cts = nib.load(ct_file[0])
data_cts = cts.get_fdata()

glob_search = os.path.join(train_files[0], '*lung*.nii')
lung_file = glob.glob(glob_search)
print('Lung mask filename: ', lung_file[0])
lung_masks = nib.load(lung_file[0])
data_lungs = lung_masks.get_fdata()

glob_search = os.path.join(train_files[0], '*infection*.nii')
infect_file = glob.glob(glob_search)
print('Infection mask filename: ', infect_file[0])
infect_masks = nib.load(infect_file[0])
data_infects = infect_masks.get_fdata()

height, width, slices = data_cts.shape
sel_slices = range(70, 240, 30)

data_cts = np.rot90(np.array(data_cts))
data_lungs = np.rot90(np.array(data_lungs))
data_infects = np.rot90(np.array(data_infects))

data_cts = np.reshape(np.rollaxis(data_cts, 2), (slices,height,width))
data_lungs = np.reshape(np.rollaxis(data_lungs, 2), (slices,height,width))
data_infects = np.reshape(np.rollaxis(data_infects, 2), (slices,height,width))

data_cts = data_cts[sel_slices, :, :]
data_lungs = data_lungs[sel_slices, :, :]
data_infects = data_infects[sel_slices, :, :]

bounds = [img_size, img_size, 0, 0]
for ii in range(data_cts.shape[0]) :
    img = cv.resize(data_cts[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    B = make_lungmask(img, img_size=img_size, display_flag=False)
    bounds[0] = min(bounds[0], B[0])
    bounds[1] = min(bounds[1], B[1])
    bounds[2] = max(bounds[2], B[2])
    bounds[3] = max(bounds[3], B[3])
    
fig, axes = plt.subplots(3, 6, figsize=(18,6))    
for ii in range(data_cts.shape[0]):
    img_ct = cv.resize(data_cts[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    img_lungs = cv.resize(data_lungs[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
    img_infec = cv.resize(data_infects[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)

    axes[0,ii].imshow(crop_(img_ct, bounds), cmap='bone')
    axes[0,ii].set_title("CT scan")
    axes[0,ii].set_xticks([]); axes[0,ii].set_yticks([])
    
    axes[1,ii].imshow(crop_(img_lungs, bounds), cmap='Greens')
    axes[1,ii].set_title("Lungs mask")
    axes[1,ii].set_xticks([]); axes[1,ii].set_yticks([])

    axes[2,ii].imshow(crop_(img_infec, bounds), cmap='Reds')
    axes[2,ii].set_title("Infection mask")
    axes[2,ii].set_xticks([]); axes[2,ii].set_yticks([])
# Out:
# CT filename:  ../training-set/patient01/patient01-ctscan.nii
# Lung mask filename:  ../training-set/patient01/patient01-lung_mask.nii
# Infection mask filename:  ../training-set/patient01/patient01-infection_mask.nii

# %% [markdown]
# # 3. Load all the data

# %%
cts_all = []
lungs_all = []
infects_all = []

for fnum in tqdm.tqdm(range(len(train_files))) :
    glob_search = os.path.join(train_files[fnum], '*ctscan*.nii')
    ct_file = glob.glob(glob_search)
    cts = nib.load(ct_file[0])
    data_cts = cts.get_fdata()

    glob_search = os.path.join(train_files[fnum], '*lung*.nii')
    lung_file = glob.glob(glob_search)
    lung_masks = nib.load(lung_file[0])
    data_lungs = lung_masks.get_fdata()

    glob_search = os.path.join(train_files[fnum], '*infection*.nii')
    infect_file = glob.glob(glob_search)
    infect_masks = nib.load(infect_file[0])
    data_infects = infect_masks.get_fdata()

    height, width, slices = data_cts.shape
    sel_slices = range(round(slices*0.2), round(slices*0.8))

    data_cts = np.rot90(np.array(data_cts))
    data_lungs = np.rot90(np.array(data_lungs))
    data_infects = np.rot90(np.array(data_infects))

    data_cts = np.reshape(np.rollaxis(data_cts, 2), (slices,height,width))
    data_lungs = np.reshape(np.rollaxis(data_lungs, 2), (slices,height,width))
    data_infects = np.reshape(np.rollaxis(data_infects, 2), (slices,height,width))

    data_cts = data_cts[sel_slices, :, :]
    data_lungs = data_lungs[sel_slices, :, :]
    data_infects = data_infects[sel_slices, :, :]

    bounds = [img_size, img_size, 0, 0]
    for ii in range(data_cts.shape[0]) :
        img = cv.resize(data_cts[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        B = make_lungmask(img, img_size=img_size, display_flag=False)
        bounds[0] = min(bounds[0], B[0])
        bounds[1] = min(bounds[1], B[1])
        bounds[2] = max(bounds[2], B[2])
        bounds[3] = max(bounds[3], B[3])

    for ii in range(data_cts.shape[0]):
        img = cv.resize(data_cts[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        cp_img = crop_(img, bounds)
        cts_all.append(cp_img)
        
        img = cv.resize(data_lungs[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        cp_img = crop_(img, bounds)
        lungs_all.append(cp_img)

        img = cv.resize(data_infects[ii], dsize=(img_size, img_size), interpolation=cv.INTER_AREA)
        cp_img = crop_(img, bounds)
        infects_all.append(cp_img)
# Out:
# 100%|██████████| 19/19 [03:49<00:00, 12.08s/it]

# %%
print('Total numer of slices: {}'.format(len(cts_all)))
# Out:
# Total numer of slices: 2057

# %% [markdown]
# # 4. Resize and reshape
#
# To speed up the training, we are going to downsample images to 100x100. This, however, may reduce network performance.

# %%
num_pix = 100
del_lst = []
for ii in tqdm.tqdm(range(len(cts_all))) :
    try :
        cts_all[ii] = cv.resize(cts_all[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        cts_all[ii] = np.reshape(cts_all[ii], (num_pix, num_pix, 1))

        lungs_all[ii] = cv.resize(lungs_all[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        lungs_all[ii] = np.reshape(lungs_all[ii], (num_pix, num_pix, 1))

        infects_all[ii] = cv.resize(infects_all[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        infects_all[ii] = np.reshape(infects_all[ii], (num_pix, num_pix, 1))
    except :
        del_lst.append(ii)
        
for idx in del_lst[::-1] :
    del cts_all[idx]
    del lungs_all[idx]
    del infects_all[idx]
# Out:
# 100%|██████████| 2057/2057 [00:01<00:00, 1092.35it/s]

# %% [markdown]
# **Visualizing a preprocessed sample**

# %%
fig, axes = plt.subplots(1, 3, figsize=(9,3))

axes[0].imshow(cts_all[450][:, :, 0])
axes[0].set_title("Cropped CT")

axes[1].imshow(lungs_all[450][:, :, 0], cmap='Greens')
axes[1].set_title("Lungs")

axes[2].imshow(infects_all[450][:, :, 0], cmap='Reds')
axes[2].set_title("Infection");

# %% [markdown]
# **<font color='blue'>Notice how the infection can be distinguised clearly after enhancement.**

# %% [markdown]
# ### Dump the preprocessed data

# %%
with open('../outputs/preprocessed_data.cp', 'wb') as myfile:
    pickle.dump({'cts': cts_all, 'lungs': lungs_all, 'infects': infects_all}, myfile)

# %%
infect_bool = np.ones((1, len(infects_all)))
for ii in range(len(infects_all)):
    if np.unique(infects_all[ii]).size == 1:
        infect_bool[0, ii] = 0
        
print("Number of CTs with no infection: {:03d}".format(len(infects_all)-int(infect_bool.sum())))

#for index in sorted(no_masks, reverse = True):  
#    del infections[index]  
#    del cts[index]
# Out:
# Number of CTs with no infection: 564

# %% [markdown]
# * Saving the numpy arrays to later reuse the same preprocessing for other models rather than doing it again.
#
#
# # 5. Data augmentation pipeline

# %%
ia.seed(1)

seq = iaa.Sequential([
    iaa.Fliplr(0.5), # horizontal flips
    iaa.Flipud(0.5), # vertical flips
    
    # Apply affine transformations to each image.
    # Scale/zoom them, translate/move them, rotate them and shear them.
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)}, # scale images
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-15, 15),
        shear=(-15, 15)
    )
], random_order=True) # apply augmenters in random order

# %%
num_augs = round(len(cts_all)/2.)
rand_idx = np.random.randint(0, len(cts_all), size=num_augs)

sample_cts = [cts_all[ii] for ii in rand_idx]
sample_lungs = [lungs_all[ii] for ii in rand_idx]
sample_infects = [infects_all[ii] for ii in rand_idx]

# %%
seq_det = seq.to_deterministic()
cts_aug = seq_det.augment_images(sample_cts)
lungs_aug = seq_det.augment_images(sample_lungs)
infects_aug = seq_det.augment_images(sample_infects)

# %%
fig, axes = plt.subplots(3, 5, figsize=(15,9))
for ii in range(5) :
    axes[0, ii].imshow(cts_aug[ii*45][:, :, 0])
    axes[0, ii].set_title("Enhanced & Cropped CT")

    axes[1, ii].imshow(lungs_aug[ii*45][:, :, 0], cmap='Greens')
    axes[1, ii].set_title("Lungs")

    axes[2, ii].imshow(infects_aug[ii*45][:, :, 0], cmap='Reds')
    axes[2, ii].set_title("Infection");

# %% [markdown]
# #### Pool augmented data and convert it

# %%
cts_all = tf.convert_to_tensor(np.asarray(cts_all))
cts_aug = tf.convert_to_tensor(np.asarray(cts_aug))
lungs_all = tf.convert_to_tensor(np.asarray(lungs_all))
lungs_aug = tf.convert_to_tensor(np.asarray(lungs_aug))
infects_all = tf.convert_to_tensor(np.asarray(infects_all))
infects_aug = tf.convert_to_tensor(np.asarray(infects_aug))

cts = tf.keras.backend.concatenate((cts_all, cts_aug), axis=0)
lungs = tf.concat([lungs_all, lungs_aug], axis=0)
infects = tf.concat([infects_all, infects_aug], axis=0)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-23-9aa144c36b27> in <module>
#       6 infects_aug = tf.convert_to_tensor(np.asarray(infects_aug))
#       7
# ----> 8 cts = tf.keras.backend.concatenate((cts_all, cts_aug), axis=0)
#       9 lungs = tf.concat([lungs_all, lungs_aug], axis=0)
#      10 infects = tf.concat([infects_all, infects_aug], axis=0)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py in concatenate(tensors, axis)
#    2879     return ragged_concat_ops.concat(tensors, axis)
#    2880   else:
# -> 2881     return array_ops.concat([to_dense(x) for x in tensors], axis)
#    2882
#    2883
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in concat(values, axis, name)
#    1652           dtype=dtypes.int32).get_shape().assert_has_rank(0)
#    1653       return identity(values[0], name=name)
# -> 1654   return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#    1655
#    1656
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in concat_v2(values, axis, name)
#    1205       return _result
#    1206     except _core._NotOkStatusException as e:
# -> 1207       _ops.raise_from_not_ok_status(e, name)
#    1208     except _core._FallbackException:
#    1209       pass
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# ~/anaconda3/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run ConcatV2: Dst tensor is not initialized. [Op:ConcatV2] name: concat

# %%
indices = tf.range(start=0, limit=cts.shape[0], dtype=tf.int32)
shuffled_indices = tf.random.shuffle(indices)
                       
cts = tf.gather(cts, shuffled_indices)
lungs = tf.gather(lungs, shuffled_indices)
infects = tf.gather(infects, shuffled_indices)

print(cts.shape, lungs.shape, infects.shape)

# %% [markdown]
# #### Save augmented data

# %%
with open('../outputs/augmented_data.npy', 
        {'cts': cts, 'lungs': lungs, 'infects': infects})

# %% [markdown]
# **Just overlaying infection masks over the corresponding CT scans**

# %%
def plot_cts_infects(ct, infect, axes) :

    axes[0].imshow(ct[:,:,0], cmap='bone')
    axes[0].set_title('CT image')

    axes[1].imshow(ct[:,:,0], cmap='bone')
    axes[1].imshow(infect[:,:,0], alpha=0.5, cmap='Reds')
    axes[1].set_title('Infection')

# %%
fig, axes = plt.subplots(2, 5, figsize=(15,6))

for ii, idx in enumerate(range(280, 400, 25)) :
    plot_cts_infects(cts[idx], infects[idx], list(axes[:,ii]))

# %% [markdown]
# # 6. Defining evaluation metrics
#
# The most commonly used metrics for image segmentation are the IoU and the Dice Coefficient. The Dice Coefficient is 2 times the Area of overlap divided by the total number of pixels in both images (true and predicted). The Dice coefficient is very similar to the IoU, and they both range from 0 to 1, with 1 signifying the greatest similarity between predicted and truth.
#
# See https://github.com/keras-team/keras/issues/9395

# %%
def dice(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3])
    dice = K.mean((2. * intersection + smooth)/(union + smooth), axis=0)
    return dice

def dice_loss(y_true, y_pred):
    loss = 1 - dice(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred): #Binary Cross-Entropy
    loss = 0.5*losses.binary_crossentropy(y_true, y_pred) + 0.5*dice_loss(y_true, y_pred)
    return loss

def tversky_loss(y_true, y_pred):
    alpha, beta  = 0.5, 0.5
    ones = K.ones(K.shape(y_true))
    p0 = y_pred
    p1 = ones-y_pred
    g0 = y_true
    g1 = ones-y_true
    num = K.sum(p0*g0, (0,1,2))
    den = num + alpha*K.sum(p0*g1,(0,1,2)) + beta*K.sum(p1*g0,(0,1,2))
    T = K.sum(num/den) 
    Ncl = K.cast(K.shape(y_true)[-1], 'float32')
    return Ncl-T

def weighted_bce_loss(y_true, y_pred, weight):
    epsilon = 1e-7
    y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
    logit_y_pred = K.log(y_pred / (1. - y_pred))
    loss = weight * (logit_y_pred * (1. - y_true) + 
                     K.log(1. + K.exp(-K.abs(logit_y_pred))) + 
                     K.maximum(-logit_y_pred, 0.))
    return K.sum(loss) / K.sum(weight)

def weighted_dice_loss(y_true, y_pred, weight):
    smooth = 1.
    w, m1, m2 = weight, y_true, y_pred
    intersection = (m1*m2)
    score = (2.*K.sum(w*intersection) + smooth) / (K.sum(w*m1) + K.sum(w*m2) + smooth)
    loss = 1. - K.sum(score)
    return loss

def weighted_bce_dice_loss(y_true, y_pred):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')
    averaged_mask = K.pool2d(y_true, pool_size=(50, 50), strides=(1, 1), 
                             padding='same', pool_mode='avg')
    weight = K.ones_like(averaged_mask)
    w0 = K.sum(weight)
    weight = 5. * K.exp(-5.*K.abs(averaged_mask - 0.5))
    w1 = K.sum(weight)
    weight *= (w0 / w1)
    loss = 0.5*weighted_bce_loss(y_true, y_pred, weight) + 0.5*dice_loss(y_true, y_pred)
    return loss

# %% [markdown]
# # 7. Cosine Annealing Learning Rate
#
# An effective snapshot ensemble requires training a neural network with an aggressive learning rate schedule.
#
# The cosine annealing schedule is an example of an aggressive learning rate schedule where learning rate starts high and is dropped relatively rapidly to a minimum value near zero before being increased again to the maximum.
#
# We can implement the schedule as described in the 2017 paper “Snapshot Ensembles: Train 1, get M for free.” The equation requires the total training epochs, maximum learning rate, and number of cycles as arguments as well as the current epoch number. The function then returns the learning rate for the given epoch.
#
# See https://machinelearningmastery.com/snapshot-ensemble-deep-learning-neural-network/

# %%
# define custom learning rate schedule
class CosineAnnealingLearningRateSchedule(callbacks.Callback):
    # constructor
    def __init__(self, n_epochs, n_cycles, lrate_max, verbose=0):
        self.epochs = n_epochs
        self.cycles = n_cycles
        self.lr_max = lrate_max
        self.lrates = list()
 
    # calculate learning rate for an epoch
    def cosine_annealing(self, epoch, n_epochs, n_cycles, lrate_max):
        epochs_per_cycle = np.floor(n_epochs/n_cycles)
        cos_inner = (np.pi * (epoch % epochs_per_cycle)) / (epochs_per_cycle)
        return lrate_max/2 * (np.cos(cos_inner) + 1)
 
    # calculate and set learning rate at the start of the epoch
    def on_epoch_begin(self, epoch, logs=None):
        # calculate learning rate
        lr = self.cosine_annealing(epoch, self.epochs, self.cycles, self.lr_max)
        # set learning rate
        K.set_value(self.model.optimizer.lr, lr)
        # log value
        self.lrates.append(lr)

# %%
# define learning rate callback
n_epochs = 200
lrmax = 0.002
n_cycles = n_epochs / 25
lr_cb = CosineAnnealingLearningRateSchedule(n_epochs, n_cycles, lrmax)

# %% [markdown]
# * All the hyperparameters are put in place after repeating trial and error for a fixed number of epochs.

# %% [markdown]
# # 8. Convolutional Neural Network
#
# #### Model building blocks
#
# These two downsample images and have the option to be trainable or not.

# %%
def downsampling_block_1 (x_in, conv2Dfilters, maxpool2Dsize=(2,2), trainable=True) :
    x = Conv2D(conv2Dfilters, (3,3), activation='relu', padding='same', 
               kernel_initializer="he_normal", trainable=trainable) (x_in)
    x = Conv2D(conv2Dfilters, (3, 3), activation='relu', padding='same', 
               kernel_initializer="he_normal", trainable=trainable) (x)
    x_inter = BatchNormalization(trainable=trainable) (x)
    x = MaxPooling2D(maxpool2Dsize) (x_inter) 
    x = Dropout(0.2)(x) 
    
    return x, x_inter

def downsampling_block_2 (x_in, conv2Dfilters, trainable=True) :
    x = BatchNormalization(trainable=trainable) (x_in)
    x = Conv2D(conv2Dfilters, (3, 3), activation='relu', padding='same', 
               kernel_initializer="he_normal", trainable=trainable) (x)
    x = Conv2D(conv2Dfilters, (3, 3), activation='relu', padding='same', 
               kernel_initializer="he_normal", trainable=trainable) (x) 
    
    return x

# %% [markdown]
# Our model consists of one single input (CT images) and two outputs (lung and infection masks). To efficently train the model, we can start training the first stage that generates lung masks by setting `trainable=False` in the infection stage. Then, train the second stage only by fixing the first stage, and finally train the whole network.

# %%
## Note: dimensions are listed for a 100x100 input images
def single_stage_seg(x_input, num_filters, trainable=True) :
    
    x, x1 = downsampling_block_1 (x_input, num_filters[0], maxpool2Dsize=(2,2), trainable=trainable) #x: 50x50
    x, x2 = downsampling_block_1 (x, num_filters[1], maxpool2Dsize=(2,2), trainable=trainable) #x: 25x25
    x, _ = downsampling_block_1 (x, num_filters[2], maxpool2Dsize=(1,1), trainable=trainable) #x: 25x25
    x, _ = downsampling_block_1 (x, num_filters[3], maxpool2Dsize=(1,1), trainable=trainable) #x: 25x25

    x = downsampling_block_2 (x, num_filters[3], trainable=trainable) #x: 25x25
    
    x = Conv2DTranspose(num_filters[2], (2, 2), strides=(2,2), padding='same', trainable=trainable) (x) #x: 50x50
    x = downsampling_block_2 (x, num_filters[2], trainable=trainable) #x: 50x50

    x = Conv2DTranspose(num_filters[1], (2, 2), padding='same', trainable=trainable) (x) #x: 50x50
    x = concatenate([x, x2]) #x: 50x50
    x = downsampling_block_2 (x, num_filters[1], trainable=trainable) #x: 50x50

    x = Conv2DTranspose(num_filters[0], (2, 2), strides=(2,2), padding='same', trainable=trainable) (x) #x: 100x100
    x = concatenate([x, x1], axis=3) #x: 100x100
    x = downsampling_block_2 (x, num_filters[0], trainable=trainable) #x: 100x100
    
    return x

# %% [markdown]
# #### keras model with one input (CTs) and two segmented output (lungs & infections)

# %%
def cts_model(input_shape, num_filters=[32,128,128,256]) :
    
    x_input = Input(input_shape)
    
    ###  LUNG SEGMENTATION
    x = single_stage_seg(x_input, num_filters, trainable=False)
    
    lung_seg = Conv2D(1, (1, 1), activation='sigmoid', 
                      name='lung_output', trainable=False)(x) # identifying lungs

    ###  INFECTION SEGMENTATION
    x = single_stage_seg(lung_seg, num_filters, trainable=True)

    infect_seg = Conv2D(1, (1, 1), activation='sigmoid', 
                        name='infect_output', trainable=True)(x) # identifying infections

    model = Model(inputs=x_input, outputs=[lung_seg, infect_seg], name='cts_model')
    
    return model

# %%
strategy = tf.distribute.MirroredStrategy()
print('Number of devices {}'.format(strategy.num_replicas_in_sync))


with strategy.scope() :
    ctsModel = cts_model(cts.shape[1:])

ctsModel.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices 1
# Model: "cts_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 100, 100, 1) 0
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 100, 100, 32) 320         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 100, 100, 32) 9248        conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 100, 100, 32) 128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 50, 50, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 50, 50, 32)   0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 50, 50, 128)  36992       dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 50, 50, 128)  512         conv2d_35[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 25, 25, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 25, 25, 128)  0           max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 25, 25, 128)  147584      dropout_9[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 25, 25, 128)  147584      conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 25, 25, 128)  512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 25, 25, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 25, 25, 128)  0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 25, 25, 256)  295168      dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 25, 25, 256)  590080      conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 25, 25, 256)  1024        conv2d_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 25, 25, 256)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 25, 25, 256)  0           max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 25, 25, 256)  1024        dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 25, 25, 256)  590080      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 25, 25, 256)  590080      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 50, 50, 128)  131200      conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 50, 50, 128)  512         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 50, 50, 128)  147584      batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 50, 50, 128)  65664       conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 50, 50, 256)  0           conv2d_transpose_7[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 50, 50, 256)  1024        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 50, 50, 128)  295040      batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 100, 100, 32) 16416       conv2d_45[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 100, 100, 64) 0           conv2d_transpose_8[0][0]
#                                                                  batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 100, 100, 64) 256         concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 100, 100, 32) 18464       batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 100, 100, 32) 9248        conv2d_46[0][0]
# __________________________________________________________________________________________________
# lung_output (Conv2D)            (None, 100, 100, 1)  33          conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 100, 100, 32) 320         lung_output[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 100, 100, 32) 9248        conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 100, 100, 32) 128         conv2d_49[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 50, 50, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 50, 50, 32)   0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 50, 50, 128)  36992       dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 50, 50, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 25, 25, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 25, 25, 128)  0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 25, 25, 128)  147584      dropout_13[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 25, 25, 128)  147584      conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 25, 25, 128)  512         conv2d_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 25, 25, 128)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 25, 25, 128)  0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 25, 25, 256)  295168      dropout_14[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 25, 25, 256)  590080      conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 25, 25, 256)  1024        conv2d_55[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 25, 25, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 25, 25, 256)  0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 25, 25, 256)  1024        dropout_15[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 25, 25, 256)  590080      batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 25, 25, 256)  590080      conv2d_56[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 50, 50, 128)  131200      conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 50, 50, 128)  512         conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 50, 50, 128)  147584      batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_10 (Conv2DTran (None, 50, 50, 128)  65664       conv2d_59[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 50, 50, 256)  0           conv2d_transpose_10[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 50, 50, 256)  1024        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 50, 50, 128)  295040      batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 50, 50, 128)  147584      conv2d_60[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_11 (Conv2DTran (None, 100, 100, 32) 16416       conv2d_61[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 100, 100, 64) 0           conv2d_transpose_11[0][0]
#                                                                  batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 100, 100, 64) 256         concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 100, 100, 32) 18464       batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 100, 100, 32) 9248        conv2d_62[0][0]
# __________________________________________________________________________________________________
# infect_output (Conv2D)          (None, 100, 100, 1)  33          conv2d_63[0][0]
# ==================================================================================================
# Total params: 7,077,058
# Trainable params: 3,536,033
# Non-trainable params: 3,541,025
# __________________________________________________________________________________________________

# %% [markdown]
# #### Callback (model checkpointing with the highest validation dice coefficient)

# %%
epochs = n_epochs

checkpoint_fpath = "../outputs/weights_final_nb-2.hdf5"
cts_checkpoint_cb = callbacks.ModelCheckpoint(checkpoint_fpath, 
                                              monitor='val_infect_output_dice', 
                                              save_best_only=True, 
                                              mode='max', 
                                              verbose=1,
                                              save_weights_only=True)

# %% [markdown]
# # 9. Split data into train and validation sets

# %%
train_size = int(0.9*cts.shape[0])

X_train, yl_train, yi_train = (cts[:train_size]/255, 
                               lungs[:train_size], 
                               infects[:train_size])

X_valid, yl_valid, yi_valid = (cts[train_size:]/255, 
                               lungs[train_size:],
                               infects[train_size:])

print(X_train.shape, yl_train.shape, yi_train.shape)
print(X_valid.shape, yl_valid.shape, yi_valid.shape)
# Out:
# (2776, 100, 100, 1) (2776, 100, 100, 1) (2776, 100, 100, 1)
# (309, 100, 100, 1) (309, 100, 100, 1) (309, 100, 100, 1)

# %% [markdown]
# # 10. Training

# %%
batch_size = 8
optim = optimizers.Adam(lr=1e-4, beta_1=0.9, beta_2=0.99)

loss_dict = {'lung_output': bce_dice_loss, 'infect_output': bce_dice_loss}
loss_weight_dict = {'lung_output': 0.5, 'infect_output': 0.5}

with strategy.scope() :
    ctsModel.compile(optimizer=optim, loss=loss_dict, loss_weights=loss_weight_dict, metrics=[dice])

ctsModel.load_weights("../outputs/weights_final_nb-1.hdf5")

# %%
ctsRes = ctsModel.fit(x = X_train, 
                      y = {'lung_output': yl_train, 'infect_output': yi_train}, 
                      batch_size = batch_size, 
                      epochs = epochs,
                      verbose = 1,
                      validation_data = (X_valid, 
                                         {'lung_output': yl_valid, 'infect_output': yi_valid}),
                      callbacks = [cts_checkpoint_cb])
# Out:
# Epoch 1/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0970 - lung_output_loss: -27494816.0000 - infect_output_dice: 0.1457 - loss: -13747408.0000 - infect_output_loss: 0.4839
# Epoch 00001: val_infect_output_dice improved from -inf to 0.13906, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 179ms/step - lung_output_dice: 1.0970 - lung_output_loss: -27494816.0000 - infect_output_dice: 0.1457 - loss: -13747408.0000 - infect_output_loss: 0.4839 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.1391 - val_loss: -12960983.0000 - val_infect_output_loss: 0.4906
# Epoch 2/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0959 - lung_output_loss: -27482658.0000 - infect_output_dice: 0.2321 - loss: -13741329.0000 - infect_output_loss: 0.4299
# Epoch 00002: val_infect_output_dice improved from 0.13906 to 0.23993, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0959 - lung_output_loss: -27482658.0000 - infect_output_dice: 0.2321 - loss: -13741329.0000 - infect_output_loss: 0.4299 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.2399 - val_loss: -12960983.0000 - val_infect_output_loss: 0.4218
# Epoch 3/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27510022.0000 - infect_output_dice: 0.2684 - loss: -13755011.0000 - infect_output_loss: 0.4160
# Epoch 00003: val_infect_output_dice improved from 0.23993 to 0.26301, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 178ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27510022.0000 - infect_output_dice: 0.2684 - loss: -13755011.0000 - infect_output_loss: 0.4160 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.2630 - val_loss: -12960983.0000 - val_infect_output_loss: 0.4260
# Epoch 4/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0966 - lung_output_loss: -27456746.0000 - infect_output_dice: 0.2956 - loss: -13728373.0000 - infect_output_loss: 0.4036
# Epoch 00004: val_infect_output_dice improved from 0.26301 to 0.30880, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0966 - lung_output_loss: -27456746.0000 - infect_output_dice: 0.2956 - loss: -13728373.0000 - infect_output_loss: 0.4036 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3088 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3983
# Epoch 5/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0951 - lung_output_loss: -27442528.0000 - infect_output_dice: 0.3361 - loss: -13721264.0000 - infect_output_loss: 0.3901
# Epoch 00005: val_infect_output_dice improved from 0.30880 to 0.34077, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0951 - lung_output_loss: -27442528.0000 - infect_output_dice: 0.3361 - loss: -13721264.0000 - infect_output_loss: 0.3901 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3408 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3919
# Epoch 6/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27516154.0000 - infect_output_dice: 0.3533 - loss: -13758077.0000 - infect_output_loss: 0.3861
# Epoch 00006: val_infect_output_dice improved from 0.34077 to 0.35998, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27516154.0000 - infect_output_dice: 0.3533 - loss: -13758077.0000 - infect_output_loss: 0.3861 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3600 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3871
# Epoch 7/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0954 - lung_output_loss: -27514644.0000 - infect_output_dice: 0.3613 - loss: -13757322.0000 - infect_output_loss: 0.3820
# Epoch 00007: val_infect_output_dice did not improve from 0.35998
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0954 - lung_output_loss: -27514644.0000 - infect_output_dice: 0.3613 - loss: -13757322.0000 - infect_output_loss: 0.3820 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3506 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3806
# Epoch 8/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27508344.0000 - infect_output_dice: 0.3805 - loss: -13754172.0000 - infect_output_loss: 0.3695
# Epoch 00008: val_infect_output_dice improved from 0.35998 to 0.38163, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27508344.0000 - infect_output_dice: 0.3805 - loss: -13754172.0000 - infect_output_loss: 0.3695 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3816 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3695
# Epoch 9/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0960 - lung_output_loss: -27473090.0000 - infect_output_dice: 0.3954 - loss: -13736545.0000 - infect_output_loss: 0.3595
# Epoch 00009: val_infect_output_dice did not improve from 0.38163
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0960 - lung_output_loss: -27473090.0000 - infect_output_dice: 0.3954 - loss: -13736545.0000 - infect_output_loss: 0.3595 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3186 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3992
# Epoch 10/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0959 - lung_output_loss: -27472890.0000 - infect_output_dice: 0.3989 - loss: -13736445.0000 - infect_output_loss: 0.3590
# Epoch 00010: val_infect_output_dice improved from 0.38163 to 0.40938, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0959 - lung_output_loss: -27472890.0000 - infect_output_dice: 0.3989 - loss: -13736445.0000 - infect_output_loss: 0.3590 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4094 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3539
# Epoch 11/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0959 - lung_output_loss: -27490496.0000 - infect_output_dice: 0.4093 - loss: -13745248.0000 - infect_output_loss: 0.3504
# Epoch 00011: val_infect_output_dice did not improve from 0.40938
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0959 - lung_output_loss: -27490496.0000 - infect_output_dice: 0.4093 - loss: -13745248.0000 - infect_output_loss: 0.3504 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3910 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3612
# Epoch 12/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0966 - lung_output_loss: -27447046.0000 - infect_output_dice: 0.4108 - loss: -13723523.0000 - infect_output_loss: 0.3508
# Epoch 00012: val_infect_output_dice improved from 0.40938 to 0.40950, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0966 - lung_output_loss: -27447046.0000 - infect_output_dice: 0.4108 - loss: -13723523.0000 - infect_output_loss: 0.3508 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4095 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3536
# Epoch 13/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0971 - lung_output_loss: -27488312.0000 - infect_output_dice: 0.4263 - loss: -13744156.0000 - infect_output_loss: 0.3433
# Epoch 00013: val_infect_output_dice improved from 0.40950 to 0.41233, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0971 - lung_output_loss: -27488312.0000 - infect_output_dice: 0.4263 - loss: -13744156.0000 - infect_output_loss: 0.3433 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4123 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3415
# Epoch 14/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0974 - lung_output_loss: -27485636.0000 - infect_output_dice: 0.4299 - loss: -13742818.0000 - infect_output_loss: 0.3410
# Epoch 00014: val_infect_output_dice did not improve from 0.41233
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0974 - lung_output_loss: -27485636.0000 - infect_output_dice: 0.4299 - loss: -13742818.0000 - infect_output_loss: 0.3410 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.3942 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3612
# Epoch 15/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0969 - lung_output_loss: -27482948.0000 - infect_output_dice: 0.4343 - loss: -13741474.0000 - infect_output_loss: 0.3376
# Epoch 00015: val_infect_output_dice improved from 0.41233 to 0.43776, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0969 - lung_output_loss: -27482948.0000 - infect_output_dice: 0.4343 - loss: -13741474.0000 - infect_output_loss: 0.3376 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4378 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3315
# Epoch 16/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0952 - lung_output_loss: -27470892.0000 - infect_output_dice: 0.4455 - loss: -13735446.0000 - infect_output_loss: 0.3311
# Epoch 00016: val_infect_output_dice did not improve from 0.43776
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0952 - lung_output_loss: -27470892.0000 - infect_output_dice: 0.4455 - loss: -13735446.0000 - infect_output_loss: 0.3311 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4299 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3398
# Epoch 17/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0970 - lung_output_loss: -27506786.0000 - infect_output_dice: 0.4432 - loss: -13753393.0000 - infect_output_loss: 0.3303
# Epoch 00017: val_infect_output_dice did not improve from 0.43776
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0970 - lung_output_loss: -27506786.0000 - infect_output_dice: 0.4432 - loss: -13753393.0000 - infect_output_loss: 0.3303 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4255 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3390
# Epoch 18/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0965 - lung_output_loss: -27505216.0000 - infect_output_dice: 0.4603 - loss: -13752608.0000 - infect_output_loss: 0.3221
# Epoch 00018: val_infect_output_dice improved from 0.43776 to 0.43824, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0965 - lung_output_loss: -27505216.0000 - infect_output_dice: 0.4603 - loss: -13752608.0000 - infect_output_loss: 0.3221 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4382 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3302
# Epoch 19/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27500500.0000 - infect_output_dice: 0.4559 - loss: -13750250.0000 - infect_output_loss: 0.3240
# Epoch 00019: val_infect_output_dice improved from 0.43824 to 0.45164, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27500500.0000 - infect_output_dice: 0.4559 - loss: -13750250.0000 - infect_output_loss: 0.3240 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4516 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3247
# Epoch 20/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0968 - lung_output_loss: -27502722.0000 - infect_output_dice: 0.4574 - loss: -13751361.0000 - infect_output_loss: 0.3227
# Epoch 00020: val_infect_output_dice did not improve from 0.45164
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0968 - lung_output_loss: -27502722.0000 - infect_output_dice: 0.4574 - loss: -13751361.0000 - infect_output_loss: 0.3227 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4486 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3265
# Epoch 21/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0954 - lung_output_loss: -27509580.0000 - infect_output_dice: 0.4686 - loss: -13754790.0000 - infect_output_loss: 0.3149
# Epoch 00021: val_infect_output_dice improved from 0.45164 to 0.46452, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0954 - lung_output_loss: -27509580.0000 - infect_output_dice: 0.4686 - loss: -13754790.0000 - infect_output_loss: 0.3149 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4645 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3229
# Epoch 22/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0950 - lung_output_loss: -27490688.0000 - infect_output_dice: 0.4775 - loss: -13745344.0000 - infect_output_loss: 0.3113
# Epoch 00022: val_infect_output_dice improved from 0.46452 to 0.46628, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0950 - lung_output_loss: -27490688.0000 - infect_output_dice: 0.4775 - loss: -13745344.0000 - infect_output_loss: 0.3113 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4663 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3145
# Epoch 23/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27496478.0000 - infect_output_dice: 0.4907 - loss: -13748239.0000 - infect_output_loss: 0.3047
# Epoch 00023: val_infect_output_dice improved from 0.46628 to 0.48063, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27496478.0000 - infect_output_dice: 0.4907 - loss: -13748239.0000 - infect_output_loss: 0.3047 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4806 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3073
# Epoch 24/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0977 - lung_output_loss: -27477490.0000 - infect_output_dice: 0.4893 - loss: -13738745.0000 - infect_output_loss: 0.3048
# Epoch 00024: val_infect_output_dice improved from 0.48063 to 0.48100, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0977 - lung_output_loss: -27477490.0000 - infect_output_dice: 0.4893 - loss: -13738745.0000 - infect_output_loss: 0.3048 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4810 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3148
# Epoch 25/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0952 - lung_output_loss: -27525306.0000 - infect_output_dice: 0.4878 - loss: -13762653.0000 - infect_output_loss: 0.3045
# Epoch 00025: val_infect_output_dice improved from 0.48100 to 0.48193, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0952 - lung_output_loss: -27525306.0000 - infect_output_dice: 0.4878 - loss: -13762653.0000 - infect_output_loss: 0.3045 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4819 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3078
# Epoch 26/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0963 - lung_output_loss: -27482458.0000 - infect_output_dice: 0.5028 - loss: -13741229.0000 - infect_output_loss: 0.2955
# Epoch 00026: val_infect_output_dice did not improve from 0.48193
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0963 - lung_output_loss: -27482458.0000 - infect_output_dice: 0.5028 - loss: -13741229.0000 - infect_output_loss: 0.2955 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4635 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3138
# Epoch 27/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0976 - lung_output_loss: -27492210.0000 - infect_output_dice: 0.5067 - loss: -13746105.0000 - infect_output_loss: 0.2920
# Epoch 00027: val_infect_output_dice did not improve from 0.48193
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0976 - lung_output_loss: -27492210.0000 - infect_output_dice: 0.5067 - loss: -13746105.0000 - infect_output_loss: 0.2920 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4685 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3241
# Epoch 28/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0978 - lung_output_loss: -27531798.0000 - infect_output_dice: 0.5105 - loss: -13765899.0000 - infect_output_loss: 0.2921
# Epoch 00028: val_infect_output_dice improved from 0.48193 to 0.49805, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0978 - lung_output_loss: -27531798.0000 - infect_output_dice: 0.5105 - loss: -13765899.0000 - infect_output_loss: 0.2921 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4981 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2996
# Epoch 29/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0960 - lung_output_loss: -27502544.0000 - infect_output_dice: 0.5160 - loss: -13751272.0000 - infect_output_loss: 0.2887
# Epoch 00029: val_infect_output_dice did not improve from 0.49805
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0960 - lung_output_loss: -27502544.0000 - infect_output_dice: 0.5160 - loss: -13751272.0000 - infect_output_loss: 0.2887 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4956 - val_loss: -12960983.0000 - val_infect_output_loss: 0.3045
# Epoch 30/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0964 - lung_output_loss: -27506956.0000 - infect_output_dice: 0.5239 - loss: -13753478.0000 - infect_output_loss: 0.2824
# Epoch 00030: val_infect_output_dice improved from 0.49805 to 0.49937, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0964 - lung_output_loss: -27506956.0000 - infect_output_dice: 0.5239 - loss: -13753478.0000 - infect_output_loss: 0.2824 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4994 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2923
# Epoch 31/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0959 - lung_output_loss: -27525630.0000 - infect_output_dice: 0.5325 - loss: -13762815.0000 - infect_output_loss: 0.2780
# Epoch 00031: val_infect_output_dice improved from 0.49937 to 0.50469, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0959 - lung_output_loss: -27525630.0000 - infect_output_dice: 0.5325 - loss: -13762815.0000 - infect_output_loss: 0.2780 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5047 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2963
# Epoch 32/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0976 - lung_output_loss: -27497480.0000 - infect_output_dice: 0.5388 - loss: -13748740.0000 - infect_output_loss: 0.2749
# Epoch 00032: val_infect_output_dice did not improve from 0.50469
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0976 - lung_output_loss: -27497480.0000 - infect_output_dice: 0.5388 - loss: -13748740.0000 - infect_output_loss: 0.2749 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.4947 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2964
# Epoch 33/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0962 - lung_output_loss: -27468662.0000 - infect_output_dice: 0.5325 - loss: -13734331.0000 - infect_output_loss: 0.2770
# Epoch 00033: val_infect_output_dice improved from 0.50469 to 0.51679, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0962 - lung_output_loss: -27468662.0000 - infect_output_dice: 0.5325 - loss: -13734331.0000 - infect_output_loss: 0.2770 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5168 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2856
# Epoch 34/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27506470.0000 - infect_output_dice: 0.5450 - loss: -13753235.0000 - infect_output_loss: 0.2692
# Epoch 00034: val_infect_output_dice improved from 0.51679 to 0.52110, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27506470.0000 - infect_output_dice: 0.5450 - loss: -13753235.0000 - infect_output_loss: 0.2692 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5211 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2837
# Epoch 35/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0957 - lung_output_loss: -27503490.0000 - infect_output_dice: 0.5474 - loss: -13751745.0000 - infect_output_loss: 0.2683
# Epoch 00035: val_infect_output_dice did not improve from 0.52110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0957 - lung_output_loss: -27503490.0000 - infect_output_dice: 0.5474 - loss: -13751745.0000 - infect_output_loss: 0.2683 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5193 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2866
# Epoch 36/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0955 - lung_output_loss: -27506290.0000 - infect_output_dice: 0.5502 - loss: -13753145.0000 - infect_output_loss: 0.2660
# Epoch 00036: val_infect_output_dice did not improve from 0.52110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0955 - lung_output_loss: -27506290.0000 - infect_output_dice: 0.5502 - loss: -13753145.0000 - infect_output_loss: 0.2660 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5031 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2892
# Epoch 37/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27509524.0000 - infect_output_dice: 0.5527 - loss: -13754762.0000 - infect_output_loss: 0.2660
# Epoch 00037: val_infect_output_dice did not improve from 0.52110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27509524.0000 - infect_output_dice: 0.5527 - loss: -13754762.0000 - infect_output_loss: 0.2660 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5144 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2853
# Epoch 38/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0950 - lung_output_loss: -27480666.0000 - infect_output_dice: 0.5567 - loss: -13740333.0000 - infect_output_loss: 0.2636
# Epoch 00038: val_infect_output_dice improved from 0.52110 to 0.53289, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0950 - lung_output_loss: -27480666.0000 - infect_output_dice: 0.5567 - loss: -13740333.0000 - infect_output_loss: 0.2636 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5329 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2845
# Epoch 39/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0957 - lung_output_loss: -27475118.0000 - infect_output_dice: 0.5591 - loss: -13737559.0000 - infect_output_loss: 0.2616
# Epoch 00039: val_infect_output_dice improved from 0.53289 to 0.53435, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0957 - lung_output_loss: -27475118.0000 - infect_output_dice: 0.5591 - loss: -13737559.0000 - infect_output_loss: 0.2616 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5343 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2777
# Epoch 40/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0958 - lung_output_loss: -27494654.0000 - infect_output_dice: 0.5628 - loss: -13747327.0000 - infect_output_loss: 0.2597
# Epoch 00040: val_infect_output_dice did not improve from 0.53435
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0958 - lung_output_loss: -27494654.0000 - infect_output_dice: 0.5628 - loss: -13747327.0000 - infect_output_loss: 0.2597 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5164 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2870
# Epoch 41/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0974 - lung_output_loss: -27482346.0000 - infect_output_dice: 0.5508 - loss: -13741173.0000 - infect_output_loss: 0.2652
# Epoch 00041: val_infect_output_dice did not improve from 0.53435
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0974 - lung_output_loss: -27482346.0000 - infect_output_dice: 0.5508 - loss: -13741173.0000 - infect_output_loss: 0.2652 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5315 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2779
# Epoch 42/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0962 - lung_output_loss: -27517922.0000 - infect_output_dice: 0.5699 - loss: -13758961.0000 - infect_output_loss: 0.2541
# Epoch 00042: val_infect_output_dice improved from 0.53435 to 0.53571, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0962 - lung_output_loss: -27517922.0000 - infect_output_dice: 0.5699 - loss: -13758961.0000 - infect_output_loss: 0.2541 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5357 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2802
# Epoch 43/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0963 - lung_output_loss: -27537618.0000 - infect_output_dice: 0.5708 - loss: -13768809.0000 - infect_output_loss: 0.2537
# Epoch 00043: val_infect_output_dice improved from 0.53571 to 0.53670, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0963 - lung_output_loss: -27537618.0000 - infect_output_dice: 0.5708 - loss: -13768809.0000 - infect_output_loss: 0.2537 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5367 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2718
# Epoch 44/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0953 - lung_output_loss: -27489930.0000 - infect_output_dice: 0.5817 - loss: -13744965.0000 - infect_output_loss: 0.2468
# Epoch 00044: val_infect_output_dice did not improve from 0.53670
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0953 - lung_output_loss: -27489930.0000 - infect_output_dice: 0.5817 - loss: -13744965.0000 - infect_output_loss: 0.2468 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5311 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2781
# Epoch 45/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0968 - lung_output_loss: -27506302.0000 - infect_output_dice: 0.5815 - loss: -13753151.0000 - infect_output_loss: 0.2486
# Epoch 00045: val_infect_output_dice improved from 0.53670 to 0.55597, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0968 - lung_output_loss: -27506302.0000 - infect_output_dice: 0.5815 - loss: -13753151.0000 - infect_output_loss: 0.2486 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5560 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2669
# Epoch 46/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0963 - lung_output_loss: -27461726.0000 - infect_output_dice: 0.5930 - loss: -13730863.0000 - infect_output_loss: 0.2413
# Epoch 00046: val_infect_output_dice did not improve from 0.55597
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0963 - lung_output_loss: -27461726.0000 - infect_output_dice: 0.5930 - loss: -13730863.0000 - infect_output_loss: 0.2413 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5515 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2703
# Epoch 47/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0975 - lung_output_loss: -27524432.0000 - infect_output_dice: 0.5800 - loss: -13762216.0000 - infect_output_loss: 0.2490
# Epoch 00047: val_infect_output_dice did not improve from 0.55597
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0975 - lung_output_loss: -27524432.0000 - infect_output_dice: 0.5800 - loss: -13762216.0000 - infect_output_loss: 0.2490 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5434 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2696
# Epoch 48/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0969 - lung_output_loss: -27493190.0000 - infect_output_dice: 0.5882 - loss: -13746595.0000 - infect_output_loss: 0.2437
# Epoch 00048: val_infect_output_dice improved from 0.55597 to 0.56042, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0969 - lung_output_loss: -27493190.0000 - infect_output_dice: 0.5882 - loss: -13746595.0000 - infect_output_loss: 0.2437 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5604 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2633
# Epoch 49/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0969 - lung_output_loss: -27484214.0000 - infect_output_dice: 0.5916 - loss: -13742107.0000 - infect_output_loss: 0.2414
# Epoch 00049: val_infect_output_dice improved from 0.56042 to 0.56043, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0969 - lung_output_loss: -27484214.0000 - infect_output_dice: 0.5916 - loss: -13742107.0000 - infect_output_loss: 0.2414 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5604 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2672
# Epoch 50/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0959 - lung_output_loss: -27522862.0000 - infect_output_dice: 0.6011 - loss: -13761431.0000 - infect_output_loss: 0.2361
# Epoch 00050: val_infect_output_dice did not improve from 0.56043
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0959 - lung_output_loss: -27522862.0000 - infect_output_dice: 0.6011 - loss: -13761431.0000 - infect_output_loss: 0.2361 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5552 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2700
# Epoch 51/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27494290.0000 - infect_output_dice: 0.5966 - loss: -13747145.0000 - infect_output_loss: 0.2381
# Epoch 00051: val_infect_output_dice did not improve from 0.56043
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27494290.0000 - infect_output_dice: 0.5966 - loss: -13747145.0000 - infect_output_loss: 0.2381 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5570 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2622
# Epoch 52/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0949 - lung_output_loss: -27503978.0000 - infect_output_dice: 0.6062 - loss: -13751989.0000 - infect_output_loss: 0.2327
# Epoch 00052: val_infect_output_dice did not improve from 0.56043
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0949 - lung_output_loss: -27503978.0000 - infect_output_dice: 0.6062 - loss: -13751989.0000 - infect_output_loss: 0.2327 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5586 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2668
# Epoch 53/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0965 - lung_output_loss: -27514868.0000 - infect_output_dice: 0.6064 - loss: -13757434.0000 - infect_output_loss: 0.2322
# Epoch 00053: val_infect_output_dice improved from 0.56043 to 0.56758, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 178ms/step - lung_output_dice: 1.0965 - lung_output_loss: -27514868.0000 - infect_output_dice: 0.6064 - loss: -13757434.0000 - infect_output_loss: 0.2322 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5676 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2565
# Epoch 54/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0948 - lung_output_loss: -27473878.0000 - infect_output_dice: 0.6068 - loss: -13736939.0000 - infect_output_loss: 0.2316
# Epoch 00054: val_infect_output_dice did not improve from 0.56758
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0948 - lung_output_loss: -27473878.0000 - infect_output_dice: 0.6068 - loss: -13736939.0000 - infect_output_loss: 0.2316 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5437 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2694
# Epoch 55/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0950 - lung_output_loss: -27489232.0000 - infect_output_dice: 0.6122 - loss: -13744616.0000 - infect_output_loss: 0.2299
# Epoch 00055: val_infect_output_dice did not improve from 0.56758
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0950 - lung_output_loss: -27489232.0000 - infect_output_dice: 0.6122 - loss: -13744616.0000 - infect_output_loss: 0.2299 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5568 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2701
# Epoch 56/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27507242.0000 - infect_output_dice: 0.6181 - loss: -13753621.0000 - infect_output_loss: 0.2268
# Epoch 00056: val_infect_output_dice did not improve from 0.56758
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27507242.0000 - infect_output_dice: 0.6181 - loss: -13753621.0000 - infect_output_loss: 0.2268 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5481 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2675
# Epoch 57/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0955 - lung_output_loss: -27528372.0000 - infect_output_dice: 0.6221 - loss: -13764186.0000 - infect_output_loss: 0.2242
# Epoch 00057: val_infect_output_dice improved from 0.56758 to 0.57144, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0955 - lung_output_loss: -27528372.0000 - infect_output_dice: 0.6221 - loss: -13764186.0000 - infect_output_loss: 0.2242 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5714 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2560
# Epoch 58/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27489204.0000 - infect_output_dice: 0.6284 - loss: -13744602.0000 - infect_output_loss: 0.2200
# Epoch 00058: val_infect_output_dice did not improve from 0.57144
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27489204.0000 - infect_output_dice: 0.6284 - loss: -13744602.0000 - infect_output_loss: 0.2200 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5563 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2652
# Epoch 59/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27495014.0000 - infect_output_dice: 0.6178 - loss: -13747507.0000 - infect_output_loss: 0.2264
# Epoch 00059: val_infect_output_dice did not improve from 0.57144
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27495014.0000 - infect_output_dice: 0.6178 - loss: -13747507.0000 - infect_output_loss: 0.2264 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5668 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2549
# Epoch 60/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0972 - lung_output_loss: -27506130.0000 - infect_output_dice: 0.6232 - loss: -13753065.0000 - infect_output_loss: 0.2226
# Epoch 00060: val_infect_output_dice improved from 0.57144 to 0.57563, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0972 - lung_output_loss: -27506130.0000 - infect_output_dice: 0.6232 - loss: -13753065.0000 - infect_output_loss: 0.2226 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5756 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2504
# Epoch 61/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27509120.0000 - infect_output_dice: 0.6310 - loss: -13754560.0000 - infect_output_loss: 0.2182
# Epoch 00061: val_infect_output_dice did not improve from 0.57563
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27509120.0000 - infect_output_dice: 0.6310 - loss: -13754560.0000 - infect_output_loss: 0.2182 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5714 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2536
# Epoch 62/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27493132.0000 - infect_output_dice: 0.6312 - loss: -13746566.0000 - infect_output_loss: 0.2182
# Epoch 00062: val_infect_output_dice did not improve from 0.57563
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27493132.0000 - infect_output_dice: 0.6312 - loss: -13746566.0000 - infect_output_loss: 0.2182 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5725 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2526
# Epoch 63/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0970 - lung_output_loss: -27486084.0000 - infect_output_dice: 0.6317 - loss: -13743042.0000 - infect_output_loss: 0.2191
# Epoch 00063: val_infect_output_dice did not improve from 0.57563
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0970 - lung_output_loss: -27486084.0000 - infect_output_dice: 0.6317 - loss: -13743042.0000 - infect_output_loss: 0.2191 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5714 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2559
# Epoch 64/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0956 - lung_output_loss: -27510690.0000 - infect_output_dice: 0.6362 - loss: -13755345.0000 - infect_output_loss: 0.2162
# Epoch 00064: val_infect_output_dice improved from 0.57563 to 0.58517, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0956 - lung_output_loss: -27510690.0000 - infect_output_dice: 0.6362 - loss: -13755345.0000 - infect_output_loss: 0.2162 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5852 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2494
# Epoch 65/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0951 - lung_output_loss: -27497082.0000 - infect_output_dice: 0.6440 - loss: -13748541.0000 - infect_output_loss: 0.2125
# Epoch 00065: val_infect_output_dice improved from 0.58517 to 0.59110, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0951 - lung_output_loss: -27497082.0000 - infect_output_dice: 0.6440 - loss: -13748541.0000 - infect_output_loss: 0.2125 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5911 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2466
# Epoch 66/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0951 - lung_output_loss: -27509946.0000 - infect_output_dice: 0.6407 - loss: -13754973.0000 - infect_output_loss: 0.2128
# Epoch 00066: val_infect_output_dice did not improve from 0.59110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0951 - lung_output_loss: -27509946.0000 - infect_output_dice: 0.6407 - loss: -13754973.0000 - infect_output_loss: 0.2128 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5901 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2463
# Epoch 67/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0973 - lung_output_loss: -27499044.0000 - infect_output_dice: 0.6472 - loss: -13749522.0000 - infect_output_loss: 0.2088
# Epoch 00067: val_infect_output_dice did not improve from 0.59110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0973 - lung_output_loss: -27499044.0000 - infect_output_dice: 0.6472 - loss: -13749522.0000 - infect_output_loss: 0.2088 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5896 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2440
# Epoch 68/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0966 - lung_output_loss: -27531836.0000 - infect_output_dice: 0.6447 - loss: -13765918.0000 - infect_output_loss: 0.2098
# Epoch 00068: val_infect_output_dice did not improve from 0.59110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0966 - lung_output_loss: -27531836.0000 - infect_output_dice: 0.6447 - loss: -13765918.0000 - infect_output_loss: 0.2098 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5784 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2487
# Epoch 69/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0953 - lung_output_loss: -27480066.0000 - infect_output_dice: 0.6493 - loss: -13740033.0000 - infect_output_loss: 0.2081
# Epoch 00069: val_infect_output_dice did not improve from 0.59110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0953 - lung_output_loss: -27480066.0000 - infect_output_dice: 0.6493 - loss: -13740033.0000 - infect_output_loss: 0.2081 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5873 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2456
# Epoch 70/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0974 - lung_output_loss: -27461652.0000 - infect_output_dice: 0.6554 - loss: -13730826.0000 - infect_output_loss: 0.2042
# Epoch 00070: val_infect_output_dice did not improve from 0.59110
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0974 - lung_output_loss: -27461652.0000 - infect_output_dice: 0.6554 - loss: -13730826.0000 - infect_output_loss: 0.2042 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5707 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2556
# Epoch 71/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0965 - lung_output_loss: -27480300.0000 - infect_output_dice: 0.6554 - loss: -13740150.0000 - infect_output_loss: 0.2056
# Epoch 00071: val_infect_output_dice improved from 0.59110 to 0.59530, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0965 - lung_output_loss: -27480300.0000 - infect_output_dice: 0.6554 - loss: -13740150.0000 - infect_output_loss: 0.2056 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.5953 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2424
# Epoch 72/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0965 - lung_output_loss: -27496690.0000 - infect_output_dice: 0.6711 - loss: -13748345.0000 - infect_output_loss: 0.1967
# Epoch 00072: val_infect_output_dice improved from 0.59530 to 0.60042, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0965 - lung_output_loss: -27496690.0000 - infect_output_dice: 0.6711 - loss: -13748345.0000 - infect_output_loss: 0.1967 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6004 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2418
# Epoch 73/200
# ...
# Epoch 00176: val_infect_output_dice did not improve from 0.64857
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0963 - lung_output_loss: -27517090.0000 - infect_output_dice: 0.7868 - loss: -13758545.0000 - infect_output_loss: 0.1259 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6401 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2177
# Epoch 177/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0955 - lung_output_loss: -27540604.0000 - infect_output_dice: 0.7978 - loss: -13770302.0000 - infect_output_loss: 0.1193
# Epoch 00177: val_infect_output_dice did not improve from 0.64857
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0955 - lung_output_loss: -27540604.0000 - infect_output_dice: 0.7978 - loss: -13770302.0000 - infect_output_loss: 0.1193 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6182 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2216
# Epoch 178/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27524848.0000 - infect_output_dice: 0.7929 - loss: -13762424.0000 - infect_output_loss: 0.1223
# Epoch 00178: val_infect_output_dice did not improve from 0.64857
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27524848.0000 - infect_output_dice: 0.7929 - loss: -13762424.0000 - infect_output_loss: 0.1223 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6350 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2160
# Epoch 179/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0958 - lung_output_loss: -27484346.0000 - infect_output_dice: 0.7879 - loss: -13742173.0000 - infect_output_loss: 0.1250
# Epoch 00179: val_infect_output_dice improved from 0.64857 to 0.65012, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0958 - lung_output_loss: -27484346.0000 - infect_output_dice: 0.7879 - loss: -13742173.0000 - infect_output_loss: 0.1250 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6501 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2106
# Epoch 180/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0951 - lung_output_loss: -27447350.0000 - infect_output_dice: 0.7948 - loss: -13723675.0000 - infect_output_loss: 0.1213
# Epoch 00180: val_infect_output_dice improved from 0.65012 to 0.65434, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0951 - lung_output_loss: -27447350.0000 - infect_output_dice: 0.7948 - loss: -13723675.0000 - infect_output_loss: 0.1213 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6543 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2105
# Epoch 181/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27525002.0000 - infect_output_dice: 0.7915 - loss: -13762501.0000 - infect_output_loss: 0.1233
# Epoch 00181: val_infect_output_dice did not improve from 0.65434
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27525002.0000 - infect_output_dice: 0.7915 - loss: -13762501.0000 - infect_output_loss: 0.1233 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6323 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2174
# Epoch 182/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0952 - lung_output_loss: -27474956.0000 - infect_output_dice: 0.7951 - loss: -13737478.0000 - infect_output_loss: 0.1211
# Epoch 00182: val_infect_output_dice did not improve from 0.65434
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0952 - lung_output_loss: -27474956.0000 - infect_output_dice: 0.7951 - loss: -13737478.0000 - infect_output_loss: 0.1211 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6478 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2111
# Epoch 183/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0967 - lung_output_loss: -27509578.0000 - infect_output_dice: 0.7969 - loss: -13754789.0000 - infect_output_loss: 0.1195
# Epoch 00183: val_infect_output_dice did not improve from 0.65434
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0967 - lung_output_loss: -27509578.0000 - infect_output_dice: 0.7969 - loss: -13754789.0000 - infect_output_loss: 0.1195 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6507 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2091
# Epoch 184/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0962 - lung_output_loss: -27521650.0000 - infect_output_dice: 0.8023 - loss: -13760825.0000 - infect_output_loss: 0.1168
# Epoch 00184: val_infect_output_dice improved from 0.65434 to 0.65454, saving model to ../outputs/weights_final_nb-2.hdf5
# 347/347 [==============================] - 62s 177ms/step - lung_output_dice: 1.0962 - lung_output_loss: -27521650.0000 - infect_output_dice: 0.8023 - loss: -13760825.0000 - infect_output_loss: 0.1168 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6545 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2102
# Epoch 185/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27516206.0000 - infect_output_dice: 0.8004 - loss: -13758103.0000 - infect_output_loss: 0.1178
# Epoch 00185: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27516206.0000 - infect_output_dice: 0.8004 - loss: -13758103.0000 - infect_output_loss: 0.1178 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6337 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2171
# Epoch 186/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0962 - lung_output_loss: -27484638.0000 - infect_output_dice: 0.8011 - loss: -13742319.0000 - infect_output_loss: 0.1174
# Epoch 00186: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0962 - lung_output_loss: -27484638.0000 - infect_output_dice: 0.8011 - loss: -13742319.0000 - infect_output_loss: 0.1174 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6422 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2107
# Epoch 187/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0966 - lung_output_loss: -27477174.0000 - infect_output_dice: 0.7989 - loss: -13738587.0000 - infect_output_loss: 0.1185
# Epoch 00187: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0966 - lung_output_loss: -27477174.0000 - infect_output_dice: 0.7989 - loss: -13738587.0000 - infect_output_loss: 0.1185 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6420 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2145
# Epoch 188/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0957 - lung_output_loss: -27475852.0000 - infect_output_dice: 0.8006 - loss: -13737926.0000 - infect_output_loss: 0.1175
# Epoch 00188: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0957 - lung_output_loss: -27475852.0000 - infect_output_dice: 0.8006 - loss: -13737926.0000 - infect_output_loss: 0.1175 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6450 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2142
# Epoch 189/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0962 - lung_output_loss: -27509314.0000 - infect_output_dice: 0.7973 - loss: -13754657.0000 - infect_output_loss: 0.1190
# Epoch 00189: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0962 - lung_output_loss: -27509314.0000 - infect_output_dice: 0.7973 - loss: -13754657.0000 - infect_output_loss: 0.1190 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6338 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2182
# Epoch 190/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0967 - lung_output_loss: -27471762.0000 - infect_output_dice: 0.8010 - loss: -13735881.0000 - infect_output_loss: 0.1168
# Epoch 00190: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0967 - lung_output_loss: -27471762.0000 - infect_output_dice: 0.8010 - loss: -13735881.0000 - infect_output_loss: 0.1168 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6310 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2166
# Epoch 191/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0951 - lung_output_loss: -27511806.0000 - infect_output_dice: 0.7968 - loss: -13755903.0000 - infect_output_loss: 0.1192
# Epoch 00191: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0951 - lung_output_loss: -27511806.0000 - infect_output_dice: 0.7968 - loss: -13755903.0000 - infect_output_loss: 0.1192 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6315 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2199
# Epoch 192/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0955 - lung_output_loss: -27535404.0000 - infect_output_dice: 0.7978 - loss: -13767702.0000 - infect_output_loss: 0.1189
# Epoch 00192: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0955 - lung_output_loss: -27535404.0000 - infect_output_dice: 0.7978 - loss: -13767702.0000 - infect_output_loss: 0.1189 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6345 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2198
# Epoch 193/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0971 - lung_output_loss: -27503666.0000 - infect_output_dice: 0.8003 - loss: -13751833.0000 - infect_output_loss: 0.1176
# Epoch 00193: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0971 - lung_output_loss: -27503666.0000 - infect_output_dice: 0.8003 - loss: -13751833.0000 - infect_output_loss: 0.1176 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6513 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2099
# Epoch 194/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0967 - lung_output_loss: -27446190.0000 - infect_output_dice: 0.8039 - loss: -13723095.0000 - infect_output_loss: 0.1156
# Epoch 00194: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0967 - lung_output_loss: -27446190.0000 - infect_output_dice: 0.8039 - loss: -13723095.0000 - infect_output_loss: 0.1156 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6391 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2139
# Epoch 195/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0959 - lung_output_loss: -27489704.0000 - infect_output_dice: 0.7990 - loss: -13744852.0000 - infect_output_loss: 0.1178
# Epoch 00195: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0959 - lung_output_loss: -27489704.0000 - infect_output_dice: 0.7990 - loss: -13744852.0000 - infect_output_loss: 0.1178 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6368 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2155
# Epoch 196/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0970 - lung_output_loss: -27490256.0000 - infect_output_dice: 0.8026 - loss: -13745128.0000 - infect_output_loss: 0.1158
# Epoch 00196: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0970 - lung_output_loss: -27490256.0000 - infect_output_dice: 0.8026 - loss: -13745128.0000 - infect_output_loss: 0.1158 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6307 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2167
# Epoch 197/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0978 - lung_output_loss: -27483758.0000 - infect_output_dice: 0.8042 - loss: -13741879.0000 - infect_output_loss: 0.1150
# Epoch 00197: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0978 - lung_output_loss: -27483758.0000 - infect_output_dice: 0.8042 - loss: -13741879.0000 - infect_output_loss: 0.1150 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6364 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2177
# Epoch 198/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27481100.0000 - infect_output_dice: 0.8071 - loss: -13740550.0000 - infect_output_loss: 0.1132
# Epoch 00198: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27481100.0000 - infect_output_dice: 0.8071 - loss: -13740550.0000 - infect_output_loss: 0.1132 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6318 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2165
# Epoch 199/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0961 - lung_output_loss: -27476028.0000 - infect_output_dice: 0.8073 - loss: -13738014.0000 - infect_output_loss: 0.1130
# Epoch 00199: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0961 - lung_output_loss: -27476028.0000 - infect_output_dice: 0.8073 - loss: -13738014.0000 - infect_output_loss: 0.1130 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6485 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2102
# Epoch 200/200
# 347/347 [==============================] - ETA: 0s - lung_output_dice: 1.0963 - lung_output_loss: -27451214.0000 - infect_output_dice: 0.8074 - loss: -13725607.0000 - infect_output_loss: 0.1128
# Epoch 00200: val_infect_output_dice did not improve from 0.65454
# 347/347 [==============================] - 61s 177ms/step - lung_output_dice: 1.0963 - lung_output_loss: -27451214.0000 - infect_output_dice: 0.8074 - loss: -13725607.0000 - infect_output_loss: 0.1128 - val_lung_output_dice: 1.1101 - val_lung_output_loss: -25921966.0000 - val_infect_output_dice: 0.6484 - val_loss: -12960983.0000 - val_infect_output_loss: 0.2101

# %%
gc.collect()
ctsModel_json = ctsModel.to_json()
with open('../outputs/ctseg-model.json', 'w') as myfile:
     myfile.write(ctsModel_json)

# %%
plt.style.use('ggplot')

fig, axes = plt.subplots(1, 2, figsize=(11,5))

axes[0].plot(ctsRes.history['lung_output_dice'], color='b', label='train-lung')
axes[0].plot(ctsRes.history['infect_output_dice'], color='c', label='train-infect')
axes[0].plot(ctsRes.history['val_lung_output_dice'], color='r', label='valid-lung')
axes[0].plot(ctsRes.history['val_infect_output_dice'], color='m', label='valid-infect')
axes[0].set_ylabel('Dice coefficient')
axes[0].set_xlabel('epoch')
axes[0].legend()
axes[0].set_ylim([0.5, 1])

axes[1].plot(ctsRes.history['lung_output_loss'], color='b', label='train-lung')
axes[1].plot(ctsRes.history['infect_output_loss'], color='c', label='train-infect')
axes[1].plot(ctsRes.history['val_lung_output_loss'], color='r', label='valid-lung')
axes[1].plot(ctsRes.history['val_infect_output_loss'], color='m', label='valid-infect')
axes[1].set_ylabel('loss')
axes[1].set_xlabel('epoch')
axes[1].set_ylim([0,1])
axes[1].legend();

# %% [markdown]
# # 11. Testing
#
# First load and process data from a test patient, predict output, and compare it with the true values.

# %%
cts = []
lungs = []
infects = []

glob_search = os.path.join(test_files[0], '*ctscan*.nii')
ct_file = glob.glob(glob_search)
ct = nib.load(ct_file[0])
data_cts = ct.get_fdata()

glob_search = os.path.join(test_files[0], '*lung*.nii')
lung_file = glob.glob(glob_search)
lung_masks = nib.load(lung_file[0])
data_lungs = lung_masks.get_fdata()

glob_search = os.path.join(test_files[0], '*infection*.nii')
infect_file = glob.glob(glob_search)
infect_masks = nib.load(infect_file[0])
data_infects = infect_masks.get_fdata()

height, width, slices = data_cts.shape
sel_slices = range(round(slices*0.2), round(slices*0.8))

data_cts = np.rot90(np.array(data_cts))
data_lungs = np.rot90(np.array(data_lungs))
data_infects = np.rot90(np.array(data_infects))

data_cts = np.reshape(np.rollaxis(data_cts, 2), (slices,height,width))
data_lungs = np.reshape(np.rollaxis(data_lungs, 2), (slices,height,width))
data_infects = np.reshape(np.rollaxis(data_infects, 2), (slices,height,width))

data_cts = data_cts[sel_slices, :, :]
data_lungs = data_lungs[sel_slices, :, :]
data_infects = data_infects[sel_slices, :, :]

for ii in range(data_cts.shape[0]):
    img_lungs = cv.resize(data_lungs[ii], dsize=(img_size, img_size), 
                            interpolation=cv.INTER_AREA)
    xmax, xmin = img_lungs.max(), img_lungs.min()
    img_lungs = (img_lungs - xmin)/(xmax - xmin)
    cropped_lungs, bounds = crop_img(img_lungs, [])
    lungs.append(cropped_lungs)

    img_ct = cv.resize(data_cts[ii], dsize=(img_size, img_size), 
                           interpolation=cv.INTER_AREA)
    xmax, xmin = img_ct.max(), img_ct.min()
    img_ct = (img_ct - xmin)/(xmax - xmin)
    clahe_ct = clahe_enhancer(img_ct, clahe, [])
    cropped_ct = crop_(clahe_ct, bounds)
    cts.append(cropped_ct)

    img_infec = cv.resize(data_infects[ii], dsize=(img_size, img_size), 
                              interpolation=cv.INTER_AREA)
    cropped_infec = crop_(img_infec, bounds)
    infects.append(cropped_infec)

# %%
del_lst = []
for ii in tqdm.tqdm(range(len(cts))) :
    try :
        cts[ii] = cv.resize(cts[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        cts[ii] = np.reshape(cts[ii], (num_pix, num_pix, 1))

        lungs[ii] = cv.resize(lungs[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        lungs[ii] = np.reshape(lungs[ii], (num_pix, num_pix, 1))

        infects[ii] = cv.resize(infects[ii], dsize=(num_pix, num_pix), interpolation=cv.INTER_AREA)
        infects[ii] = np.reshape(infects[ii], (num_pix, num_pix, 1))
    except :
        del_lst.append(ii)
        
for idx in del_lst[::-1] :
    del cts[idx]
    del lungs[idx]
    del infects[idx]
# Out:
# 100%|██████████| 55/55 [00:00<00:00, 2104.75it/s]

# %%
cts = tf.convert_to_tensor(cts)/255
lungs = tf.convert_to_tensor(lungs)
infects = tf.convert_to_tensor(infects)

print(cts.shape, lungs.shape, infects.shape)
# Out:
# (55, 100, 100, 1) (55, 100, 100, 1) (55, 100, 100, 1)

# %%
test_result = ctsModel.evaluate(x=cts, 
                                y={'lung_output': lungs, 'infect_output': infects},
                                batch_size=batch_size);

print("Test data:\t\tloss\t\tdice coeff\n\t Lung:\t\t{:0.4f}\t\t{:0.4f}\n".format(
                test_result[1], test_result[3]),
                  "\t Infection:\t{:0.4f}\t\t{:0.4f}".format(test_result[2], 
                                                             test_result[4]))
# Out:
# Test data:		loss		dice coeff
# 	 Lung:		0.2294		0.7897
#  	 Infection:	0.2579		0.7618

# %% [markdown]
# # 12. Visualize predicted outputs

# %%
yl_pred, yi_pred = ctsModel.predict(cts)

print(yl_pred.shape, yi_pred.shape)
# Out:
# (55, 100, 100, 1) (55, 100, 100, 1)

# %%
def compare_actual_and_predicted(img_num):

    fig = plt.figure(figsize=(12,7))

    plt.subplot(2,3,1)
    plt.imshow(tf.reshape(cts[img_num], [num_pix, num_pix]))
    plt.title('CT image'); plt.grid(None)

    plt.subplot(2,3,2)
    plt.imshow(tf.reshape(lungs[img_num], [num_pix, num_pix]), cmap='bone')
    plt.title('lung mask'); plt.grid(None)

    plt.subplot(2,3,3)
    plt.imshow(tf.reshape(infects[img_num], [num_pix, num_pix]), cmap='bone')
    plt.title('infection mask'); plt.grid(None)

    plt.subplot(2,3,5)
    plt.imshow(tf.reshape(yl_pred[img_num], [num_pix, num_pix]), cmap='bone')
    plt.title('predicted lung mask'); plt.grid(None)

    plt.subplot(2,3,6)
    plt.imshow(tf.reshape(yi_pred[img_num], [num_pix, num_pix]), cmap='bone')
    plt.title('predicted infection mask'); plt.grid(None)
    

compare_actual_and_predicted(40)

# %%
# model.compile(optimizer=Adam(lr = 0.0005), loss=bce_dice_loss, metrics=[sm.metrics.IOUScore(threshold=0.55)])
